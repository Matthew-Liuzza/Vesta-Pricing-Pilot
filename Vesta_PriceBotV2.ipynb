# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver import ChromeOptions
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains

import time
import pandas as pd
import numpy as np

pd.options.mode.chained_assignment = None

########### HELPER FUNCTIONS #######################

def evaluate_order(VALUE: int, CASE: str, dX: int = 5):
        
    operator = CASE.split(' ')[1]
            
    if (VALUE > 95) and (VALUE < 101):
        dX = (100 - VALUE) - 1
                
    if operator == '<':
        return VALUE - dX
    if operator == '>':
        return VALUE + dX
    return VALUE
    

######################################################



class TestLoan:
    
    loan_purpose, loan_type = '',''
    
    def __init__(self,LOAN_PURPOSE: str, LOAN_TYPE: str):
        
        self.loan_purpose = LOAN_PURPOSE
        self.loan_type = LOAN_TYPE
        
    def set_loan_parameters(self,OCCUPANCY: str, CHANNEL: str, STATE: str, PROPERTY_TYPE: str, PPP: str, INVESTOR: str, PRICING_VARIABLES: str, ID: str):
        
        self.occupancy = OCCUPANCY
        self.channel = CHANNEL
        self.state = STATE
        self.property_type = PROPERTY_TYPE
        self.ppp = PPP
        self.investor = INVESTOR
        self.pricing_variables = PRICING_VARIABLES
        self.id = ID
        
    def set_vesta_url(self,URL: str):
        
        self.vesta_url = URL
        
    def get_vesta_url(self):
        
        return self.vesta_url
    
            
    def parse_pricing_variables(self):
        
        if self.loan_type == 'Conv':
        
            dti_string = (self.pricing_variables.split('L')[0])[:-2]
            ltv_string = ('L' + (self.pricing_variables.split('L')[1]).split('C')[0])[:-2]
            fico_string = 'C' + self.pricing_variables.split('C')[1]
            
            dti_cases = dti_string.split(',')
            dti_cases[1] = 'DTI' + dti_cases[1]

            ltv_cases = ltv_string.split(',',3)
            ltv_cases[1] = 'LTV' + ltv_cases[1]
            ltv_cases[2] = 'LTV' + ltv_cases[2]

            fico_cases = fico_string.split(',')
            fico_cases[1] = 'Credit_Score' + fico_cases[1]
            
            cases = [0] * (len(dti_cases) * len(ltv_cases) * len(fico_cases))
            
            idx = 0
            for i in range(len(dti_cases)):
                for j in range(len(ltv_cases)):
                    for k in range(len(fico_cases)):
                        
                        dti_ijk = evaluate_order(VALUE=int(dti_cases[i][-2:]),CASE=dti_cases[i])
                        ltv_ijk = evaluate_order(VALUE=int(ltv_cases[j][-2:]),CASE=ltv_cases[j])
                        fico_ijk = evaluate_order(VALUE=int(fico_cases[k][-3:]),CASE=fico_cases[k])
                        
                        cases[idx] = (dti_ijk,ltv_ijk,fico_ijk,dti_cases[i] + ' ' + ltv_cases[j] + ' ' + fico_cases[k])
                        idx += 1
                        
            
        if self.loan_type == 'BS':
            
            Amonth_string = self.pricing_variables.split(',')[0]
            Bmonth_string = (self.pricing_variables.split(',')[1])[1:]
            
            caseA = ( int(Amonth_string[0:2]), Amonth_string )
            caseB = ( int(Bmonth_string[0:2]), Bmonth_string)
            
            cases = [caseA, caseB]
            
        
        if self.loan_type == 'DSCR':
            cases = [(0,0,0,' ')] * 3
            
        
        return cases

class Web_Pilot:
    
    browser, service = None, None
    actions = None
    
    investor_dict = {
        
        "PennyMac": "Pennymac",
        "UWM": "United Wholesale Mortgage",
        "Deephaven": "Deephaven",
        "NewRez": "Newrez",
        "Verus": "Verus",
        "Arc": "Arc Home Loans",
        "Mr. Cooper": "Mr. Cooper"
        
    }
    
    
    # initialize webdriver with the path to chromedriver.exe
    def __init__(self):
                
        self.opts = ChromeOptions()
        self.opts.add_argument("--no-sandbox")
        
        self.browser = webdriver.Chrome(options=self.opts)
        self.actions = ActionChains(self.browser)
        
    def wait(self,dt: float=1):
        time.sleep(dt)
        
    def open_page(self,URL: str):
        self.browser.get(URL)
        
    def close_browser(self):
        self.browser.close()
    
    def add_input(self, BY: By, VALUE: str, TEXT: str):
        field = self.browser.find_element(by=BY,value=VALUE)
        field.send_keys(TEXT)
        self.wait(0.5)
            
    def enter_input(self,BY: By, VALUE: str, GLOBAL: bool = False):
        
        if GLOBAL:
            
            field = self.browser.find_element(by=BY,value=VALUE)
            self.actions.move_to_element(field)
            self.actions.click()
            self.actions.perform()
            
        else:
                
            field = self.browser.find_element(by=BY,value=VALUE)
            field.send_keys(Keys.ENTER)
            self.wait(0.5)
    
    def moveDown_input(self,BY: By, VALUE: str):
        field = self.browser.find_element(by=BY,value=VALUE)
        field.send_keys(Keys.DOWN)
        self.wait(0.5)
        
    def select_input(self, BY: By, VALUE: str, TEXT: str):
        field = Select(self.browser.find_element(by=BY,value=VALUE))
        field.select_by_index(1)
        self.wait(0.5)
        
    def clear_input(self, BY: By, VALUE: str, KEYS: int=1):
        field = self.browser.find_element(by=BY,value=VALUE)
        
        for i in range(KEYS):
            field.send_keys(Keys.BACK_SPACE)
            self.wait(0.5)
        
        
    def click_button(self, BY: By, VALUE: str):
        button = self.browser.find_element(by=BY,value=VALUE)
        button.click()
        self.wait(0.5)
        
    def select_WebElements(self, BY: By, VALUE: str):
        return self.browser.find_elements(by=BY,value=VALUE)
    
    def select_WebElement(self,BY: By, VALUE: str):
        return self.browser.find_element(by=BY,value=VALUE)
    
    def getText_WebElement(self,BY: By, VALUE: str):
        return self.select_WebElement(BY=BY,VALUE=VALUE).text
    
    
        

    
class Price_Engine_Pilot(Web_Pilot):
    browser, service = None, None
    username, password = '',''
    actions = None
    
    def __init__(self,USERNAME: str, PASSWORD: str):
        self.username = USERNAME
        self.password = PASSWORD
        
        Web_Pilot.__init__(self)
        
    
    def login_vesta(self):
        
        # Login using Gmail
        self.click_button(BY=By.CLASS_NAME,VALUE="_ProviderLoginButton-module_gsi-material-button_I1g3crH")
        
        # Enter Gmail and click next
        self.add_input(BY=By.CLASS_NAME, VALUE='whsOnd',TEXT=self.username)
        self.click_button(BY=By.CLASS_NAME,VALUE="VfPpkd-LgbsSe-OWXEXe-k8QpJ")
        
        self.wait(2)
        
        # Enter password and click next
        self.add_input(BY=By.CLASS_NAME,VALUE='whsOnd',TEXT=self.password)
        self.click_button(BY=By.CLASS_NAME,VALUE='VfPpkd-LgbsSe-OWXEXe-k8QpJ')
        
        # User input once G-mail 2-factor approved
        input("Verify Credentials and Press Enter to Continue...")
        self.wait(2)
        
        # Open pricing engine
        self.click_button(BY=By.XPATH,VALUE='/html/body/div[1]/div[1]/div[2]/c-wiz/div/div[3]/div/div/div[2]/div/div/button')
        self.wait(10)
        
    def pull_credit(self):
        
        # toggle 'Pull credit' and click it
        self.click_button(BY=By.XPATH,VALUE='/html/body/div[1]/div/div[2]/div[1]/div/div/div/div[1]/div[2]/div[1]/div[3]/div/button')
        self.wait(2.0)
        self.enter_input(BY=By.XPATH,VALUE='/html/body/div[4]/div/div/div/div/div/div[1]/div/div[1]/div',GLOBAL=True)
        self.wait(2.0)
        
        # move cursor to 'Pull new credit report' and click it
        self.enter_input(BY=By.XPATH,VALUE='/html/body/div[5]/div/div[2]/div/div[2]/div/div/div[2]/div/div/div/div[2]/div[1]/label/span[1]/input',GLOBAL=True)
        self.wait(2.0)
        
        # move cursor to 'Next' and click it
        self.enter_input(BY=By.XPATH,VALUE='/html/body/div[5]/div/div[2]/div/div[2]/div/div/div[3]/button',GLOBAL=True)
        self.wait(2.0)
        
        # move cursor to 'Pull Credit' and click it
        self.enter_input(BY=By.XPATH,VALUE='/html/body/div[5]/div/div[2]/div/div[2]/div/div/div[3]/button',GLOBAL=True)
        self.wait(10)
        
        # press close and exit
        self.enter_input(BY=By.XPATH,VALUE='/html/body/div[5]/div/div[2]/div/div[2]/div/div/div[4]/button',GLOBAL=True)
        self.wait(1.0)
        
        
    def pull_fees(self):
        
        # toggle 'Pull fees' and click it
        self.click_button(BY=By.XPATH,VALUE='/html/body/div[1]/div/div[2]/div[1]/div/div/div/div[1]/div[2]/div[1]/div[3]/div/button')
        self.wait(2.0)
        self.enter_input(BY=By.XPATH,VALUE='/html/body/div[4]/div/div/div/div/div/div[1]/div/div[3]/div',GLOBAL=True)
        self.wait(10.0)
        
        # select 'Beeline Title'
        input_text= 'Beeline Title'
        self.add_input(BY=By.XPATH,VALUE='/html/body/div[4]/div[1]/div/div/div/div/div[2]/div/div[2]/div/div/div[2]/div[1]/div/div[1]/input',TEXT=input_text)
        self.wait(3.0)
        self.enter_input(BY=By.XPATH,VALUE='/html/body/div[4]/div[1]/div/div/div/div/div[2]/div/div[2]/div/div/div[2]/div[1]/div/div[1]/input')
        self.wait(3.0)
        
        # click 'Next'
        self.click_button(BY=By.XPATH,VALUE='/html/body/div[4]/div/div/div/div/div/div[3]/button[2]')
        self.wait(2.0)
        
        # click 'Pull fees'
        self.click_button(BY=By.XPATH,VALUE='/html/body/div[4]/div/div/div/div/div/div[3]/button[2]')
        self.wait(10.0)
        
        # click 'Confirm'
        self.click_button(BY=By.XPATH,VALUE='/html/body/div[4]/div/div/div/div/div/div[3]/button[2]')
        self.wait(10.0)



    def fetch_quotes(self):
        
        try: 
            
            # view top products
            self.click_button(BY=By.XPATH,VALUE='//*[@id="_FullScreenModal-module_modal_xmLzJ6A"]/div/div[2]/div[2]/div/div[1]/div/div/div/button')
            self.wait(2)
            
            # get quote WebElements
            quotes = self.select_WebElements(BY=By.XPATH,VALUE='//*[@id="_FullScreenModal-module_modal_xmLzJ6A"]/div/div[2]/div[2]/div/div[1]/div/div[2]/div/div/div[2]/div')
            N_quotes = len(quotes)
            self.wait(2)
            
            # construct dataframe to store quotes
            quotes_df = pd.DataFrame( columns =['Rate','Price','Investor'],index=range(N_quotes))
            quotes_df['Expired'] = False
            
            for i in range(N_quotes):
                
                # get the rate
                rate_PATH = '//*[@id="_FullScreenModal-module_modal_xmLzJ6A"]/div/div[2]/div[2]/div/div[1]/div/div[2]/div/div/div[2]/div[' + str(i+1) + ']/div/div[1]/div/div/div/div/div[2]/div'
                rate = float(self.getText_WebElement(BY=By.XPATH,VALUE=rate_PATH)[:-1])
                
                # get the price
                price_PATH = '//*[@id="_FullScreenModal-module_modal_xmLzJ6A"]/div/div[2]/div[2]/div/div[1]/div/div[2]/div/div/div[2]/div[' + str(i+1) + ']/div/div[3]/div/div/div/div/div[2]/div'
                price = float(self.getText_WebElement(BY=By.XPATH,VALUE=price_PATH))
                
                # get the investor
                investor_PATH  = '//*[@id="_FullScreenModal-module_modal_xmLzJ6A"]/div/div[2]/div[2]/div/div[1]/div/div[2]/div/div/div[2]/div[' + str(i+1) + ']/div/div[6]/div/div[1]/div/div/div[2]/div'
                investor = self.getText_WebElement(BY=By.XPATH,VALUE=investor_PATH).split('-')[0][:-1]
                
                expirationTag = False
                
                # check if product has expired
                try:
                    expirationTag_PATH = '//*[@id="_FullScreenModal-module_modal_xmLzJ6A"]/div/div[2]/div[2]/div/div[1]/div/div[2]/div/div/div[2]/div[' + str(i+1) + ']/div/div[6]/div/div[2]/div/div/div/div[2]/div'
                    expirationTag = self.getText_WebElement(BY=By.XPATH,VALUE=expirationTag_PATH)
                    expirationTag = True
                
                except NoSuchElementException:
                    pass
                
                # append metadate to quotes dataframe
                quotes_df.at[i,'Rate'] = rate
                quotes_df.at[i,'Price'] = price
                quotes_df.at[i,'Investor'] = investor
                quotes_df.at[i,'Expired'] = expirationTag
                
            
            return quotes_df
                
        except NoSuchElementException:
            pass
        
        return None
        
    
    
    def execute(self):
        
        # click 'View Mortgage Products'
        self.click_button(BY=By.XPATH,VALUE='/html/body/div[4]/div[2]/div/div[1]/div[2]/button')
        self.wait(15)
        
        return self.fetch_quotes()
        
        
    def run_pricing(self, TEST_LOAN: TestLoan, INPUT_DF: pd.DataFrame, OUTPUT_DF: pd.DataFrame, INPUT_NAME: str, OUTPUT_NAME: str, IDX: int):
        
        
        if TEST_LOAN.loan_purpose not in ['P&S','Refi','Cashout','TBD']:
            raise ValueError("Invalid Input for 'Loan Purpose.'")
        
        print("Pricing iteration #" + str(IDX))
        print(TEST_LOAN.loan_purpose)
        print(TEST_LOAN.loan_type)
        print(TEST_LOAN.state)
        print(TEST_LOAN.property_type)
        print()
        
            
           
        # get pricing variables string and return all possible cases to test 
        PARSED_pricing_variables = TEST_LOAN.parse_pricing_variables()
    
        # number of cases
        N_CASES_variables = len(PARSED_pricing_variables)
        i = 0
        
        while i < N_CASES_variables:
            
            
            if TEST_LOAN.loan_type != 'DSCR':
                
                self.wait(40)
                    
                # check if 'Hide (5 mins)' pop-up is enabled
                try:
                        
                    self.click_button(BY=By.XPATH,VALUE='/html/body/div[1]/div/div[2]/div[1]/div/div/div/div[1]/div[2]/div[1]/div[3]/div/button')
                    self.wait(2.0)
                        
                except ElementClickInterceptedException:
                        
                    self.click_button(BY=By.XPATH,VALUE='/html/body/div[2]/div/div[2]/button')
                    self.wait(2.0)
                    self.click_button(BY=By.XPATH,VALUE='/html/body/div[1]/div/div[2]/div[1]/div/div/div/div[1]/div[2]/div[1]/div[3]/div/button')
                    self.wait(2.0)
                
                # open pricing engine        
                self.enter_input(BY=By.XPATH,VALUE='/html/body/div[4]/div/div/div/div/div/div[1]/div/div[2]/div',GLOBAL=True)
                self.wait(3.0)
        
        
            if TEST_LOAN.loan_type == 'Conv':
                        
                # get DTI, LTV, FICO for specific case of specified pricing variables
                DTI_i, LTV_i, FICO_i = PARSED_pricing_variables[i][0], PARSED_pricing_variables[i][1], PARSED_pricing_variables[i][2]
                pricing_variables_i = PARSED_pricing_variables[i][3]
                                
                                
                # set Debt-to-Income ratio
                DTI_PATH = '/html/body/div[4]/div[2]/div/div[1]/div[1]/div[1]/div[2]/div/div[8]/div/div/div/div/div[2]/div[1]/div/input'
                self.clear_input(BY=By.XPATH,VALUE=DTI_PATH,KEYS=8)
                self.add_input(BY=By.XPATH,VALUE=DTI_PATH,TEXT=DTI_i)
                self.wait(0.5)
                
                # set FICO Credit Score
                FICO_PATH = '/html/body/div[4]/div[2]/div/div[1]/div[1]/div[1]/div[2]/div/div[12]/div/div/div/div/div[2]/div/div/input'
                self.clear_input(BY=By.XPATH,VALUE=FICO_PATH,KEYS=4)
                self.add_input(BY=By.XPATH,VALUE=FICO_PATH,TEXT=FICO_i)
                self.wait(0.5)
                
                # calculate new with given LTV ratio
                property_value = 400000
                loan_amount = int(round(LTV_i * property_value * 0.01,0))
                
                # set loan amount
                loan_amount_PATH = '/html/body/div[4]/div[2]/div/div[1]/div[1]/div[1]/div[2]/div/div[2]/div/div/div/div/div[2]/div[2]/div/input'
                self.clear_input(BY=By.XPATH,VALUE=loan_amount_PATH,KEYS=7)
                self.add_input(BY=By.XPATH,VALUE=loan_amount_PATH,TEXT=loan_amount)
                self.wait(0.5)
                
                # set purchase price
                purchase_price_PATH = '/html/body/div[4]/div[2]/div/div[1]/div[1]/div[1]/div[2]/div/div[3]/div/div/div/div/div[2]/div[2]/div/input'
                self.clear_input(BY=By.XPATH,VALUE=purchase_price_PATH,KEYS=7)
                self.add_input(BY=By.XPATH,VALUE=purchase_price_PATH,TEXT=property_value)
                self.wait(0.25)
        
                # set property value
                property_value_PATH = '/html/body/div[4]/div[2]/div/div[1]/div[1]/div[1]/div[2]/div/div[4]/div/div[2]/div[2]/div/input'
                self.clear_input(BY=By.XPATH,VALUE=property_value_PATH,KEYS=7)
                self.add_input(BY=By.XPATH,VALUE=property_value_PATH,TEXT=property_value)
                self.wait(0.25)
                
                # set months of reserves
                reserves = 2
                reserves_PATH = '/html/body/div[4]/div[2]/div/div[1]/div[1]/div[1]/div[2]/div/div[13]/div/div/div/div/div[2]/div/div/input'
                self.add_input(BY=By.XPATH,VALUE=reserves_PATH,TEXT=reserves)
                self.wait(0.5)
                
                # set number of units
                units_PATH = '/html/body/div[4]/div[2]/div/div[1]/div[1]/div[2]/div[2]/div/div[2]/div[1]/div[2]/div/div/input'
                self.clear_input(BY=By.XPATH,VALUE=units_PATH,KEYS=1)
                self.add_input(BY=By.XPATH,VALUE=units_PATH,TEXT=1)
                self.wait(0.5)
                
                # adjust number of units if 'Multi Family' property
                if TEST_LOAN.property_type == 'Multi Family':
    
                    self.clear_input(BY=By.XPATH,VALUE=units_PATH,KEYS=1)
                    self.add_input(BY=By.XPATH,VALUE=units_PATH,TEXT=3)
                    self.wait(0.5)
                    
                # select 'US Citizen
                input_text= 'US Citizen'
                self.add_input(BY=By.XPATH,VALUE='/html/body/div[4]/div[2]/div/div[1]/div[1]/div[3]/div[2]/div/div[2]/div/div/div/div/div[1]/div[2]/div[1]/div/div[1]/input',TEXT=input_text)
                self.wait(3.0)
                self.enter_input(BY=By.XPATH,VALUE='/html/body/div[4]/div[2]/div/div[1]/div[1]/div[3]/div[2]/div/div[2]/div/div/div/div/div[1]/div[2]/div[1]/div/div[1]/input')
                self.wait(3.0)
                
                
            if TEST_LOAN.loan_type == 'BS':
                
                # get month for term of bank statement loan and pricing variables string
                month_i, pricing_variables_i = PARSED_pricing_variables[i][0], PARSED_pricing_variables[i][1]
                                
                # set income doc type
                doc_type = 'BusinessBankStmt24Mos'
                
                if month_i == 12:
                    doc_type = 'BusinessBankStmt12Mos'   
                
                self.wait(2.0)
                self.add_input(BY=By.XPATH,VALUE='/html/body/div[4]/div[2]/div/div[1]/div[1]/div[1]/div[2]/div/div[8]/div/div/div/div/div/div[2]/div[1]/div/div[1]/input',TEXT=doc_type)
                self.wait(3.0)
                self.enter_input(BY=By.XPATH,VALUE='/html/body/div[4]/div[2]/div/div[1]/div[1]/div[1]/div[2]/div/div[8]/div/div/div/div/div/div[2]/div[1]/div/div[1]/input')
                self.wait(3.0)
                          
                # set months of reserves
                reserves = 2
                reserves_PATH = '/html/body/div[4]/div[2]/div/div[1]/div[1]/div[1]/div[2]/div/div[14]/div/div/div/div/div[2]/div/div/input'
                self.add_input(BY=By.XPATH,VALUE=reserves_PATH,TEXT=reserves)
                self.wait(0.5)
                
                # set number of units
                units_PATH = '/html/body/div[4]/div[2]/div/div[1]/div[1]/div[2]/div[2]/div/div[2]/div/div[2]/div/div/input'
                self.clear_input(BY=By.XPATH,VALUE=units_PATH,KEYS=1)
                self.add_input(BY=By.XPATH,VALUE=units_PATH,TEXT=1)
                self.wait(0.5)
                
                # adjust number of units if 'Multi Family' property
                if TEST_LOAN.property_type == 'Multi Family':
    
                    self.clear_input(BY=By.XPATH,VALUE=units_PATH,KEYS=1)
                    self.add_input(BY=By.XPATH,VALUE=units_PATH,TEXT=3)
                    self.wait(0.5)
                    
                # select 'US Citizen
                input_text= 'US Citizen'
                self.add_input(BY=By.XPATH,VALUE='/html/body/div[4]/div[2]/div/div[1]/div[1]/div[3]/div[2]/div/div[2]/div/div/div/div/div/div[2]/div[1]/div/div[1]/input',TEXT=input_text)
                self.wait(3.0)
                self.enter_input(BY=By.XPATH,VALUE='/html/body/div[4]/div[2]/div/div[1]/div[1]/div[3]/div[2]/div/div[2]/div/div/div/div/div/div[2]/div[1]/div/div[1]/input')
                self.wait(3.0)
                
                
                
            if TEST_LOAN.loan_type == 'DSCR':
                i += 1
                continue
            
            # run pricing engine and obtain dataframe of test results
            quotes_df = self.execute()
            ############ IMPLEMENT ERROR CATCHING IN PRICING ENGINE #########################
            optimal_quotes_df = self.select_optimal_quotes(QUOTES_DF=quotes_df)
            par_values_test_results_df = self.par_values_test(OPTIMAL_QUOTES_DF=optimal_quotes_df)
            
            
            OUTPUT_DF.at[IDX,'ID'] = TEST_LOAN.id
            OUTPUT_DF.at[IDX,'Loan Purpose'] = TEST_LOAN.loan_purpose
            OUTPUT_DF.at[IDX,'Occupancy'] = TEST_LOAN.occupancy
            OUTPUT_DF.at[IDX,'Channel'] = TEST_LOAN.channel
            OUTPUT_DF.at[IDX,'State'] = TEST_LOAN.state
            OUTPUT_DF.at[IDX,'Property type'] = TEST_LOAN.property_type
            OUTPUT_DF.at[IDX,'Loan Type'] = TEST_LOAN.loan_type
            OUTPUT_DF.at[IDX,'PPP'] = TEST_LOAN.ppp
            OUTPUT_DF.at[IDX,'Vesta Loan'] = TEST_LOAN.get_vesta_url()
            
            if (type(par_values_test_results_df) is not type(None)) and (par_values_test_results_df.shape[0] > 0):
                
                for j in range(len(par_values_test_results_df)):
                    
                    OUTPUT_DF.at[IDX,'ID'] = TEST_LOAN.id
                    OUTPUT_DF.at[IDX,'Loan Purpose'] = TEST_LOAN.loan_purpose
                    OUTPUT_DF.at[IDX,'Occupancy'] = TEST_LOAN.occupancy
                    OUTPUT_DF.at[IDX,'Channel'] = TEST_LOAN.channel
                    OUTPUT_DF.at[IDX,'State'] = TEST_LOAN.state
                    OUTPUT_DF.at[IDX,'Property type'] = TEST_LOAN.property_type
                    OUTPUT_DF.at[IDX,'Loan Type'] = TEST_LOAN.loan_type
                    OUTPUT_DF.at[IDX,'PPP'] = TEST_LOAN.ppp
                    OUTPUT_DF.at[IDX,'Vesta Loan'] = TEST_LOAN.get_vesta_url()
                    
                    OUTPUT_DF.at[IDX,'Rate'] = par_values_test_results_df.iat[j,0]
                    OUTPUT_DF.at[IDX,'Price'] = par_values_test_results_df.iat[j,1]
                    OUTPUT_DF.at[IDX,'Investor'] = par_values_test_results_df.iat[j,2]
                    OUTPUT_DF.at[IDX,'Pass/Fail'] = par_values_test_results_df.iat[j,3]
                    OUTPUT_DF.at[IDX,'Pricing Variables'] = pricing_variables_i
                    
                    # move back to outside once other loan_types implemented
                    IDX += 1
                    
            
            else:
                
                for j, investor in zip(list(range(len(self.investor_dict))),list(self.investor_dict.keys())):
                    
                    OUTPUT_DF.at[IDX,'ID'] = TEST_LOAN.id
                    OUTPUT_DF.at[IDX,'Loan Purpose'] = TEST_LOAN.loan_purpose
                    OUTPUT_DF.at[IDX,'Occupancy'] = TEST_LOAN.occupancy
                    OUTPUT_DF.at[IDX,'Channel'] = TEST_LOAN.channel
                    OUTPUT_DF.at[IDX,'State'] = TEST_LOAN.state
                    OUTPUT_DF.at[IDX,'Property type'] = TEST_LOAN.property_type
                    OUTPUT_DF.at[IDX,'Loan Type'] = TEST_LOAN.loan_type
                    OUTPUT_DF.at[IDX,'PPP'] = TEST_LOAN.ppp
                    OUTPUT_DF.at[IDX,'Vesta Loan'] = TEST_LOAN.get_vesta_url()
                                        
                    OUTPUT_DF.at[IDX,'Rate'] = 0
                    OUTPUT_DF.at[IDX,'Price'] = 0
                    OUTPUT_DF.at[IDX,'Investor'] = investor
                    OUTPUT_DF.at[IDX,'Pass/Fail'] = 'Fail'
                    OUTPUT_DF.at[IDX,'Pricing Variables'] = pricing_variables_i
                    
                    # move back to outside once other loan_types implemented
                    IDX += 1
                    
            # append new row
            OUTPUT_DF = pd.concat([OUTPUT_DF,OUTPUT_DF.tail(1)]).reset_index(drop=True)
                
            # re-open loan in vesta
            self.open_page(TEST_LOAN.get_vesta_url())
            self.wait(10)
            
            print("Case iteration #" + str(i))
            print(pricing_variables_i)
            print()
            print(OUTPUT_DF.tail(3))
            print()
            print()
            
            i += 1
        
        # update output dataframe
        self.wait(10)
        OUTPUT_DF.to_excel(OUTPUT_NAME)
        
        
        # remove used rows from input dataframe
        INPUT_DF = INPUT_DF.tail(INPUT_DF.shape[0] - 1)
        INPUT_DF.to_excel(INPUT_NAME)
        return IDX
    
         
         
         
            
    def select_optimal_quotes(self, QUOTES_DF: pd.DataFrame):
        
        if (type(QUOTES_DF) is type(None)) or (QUOTES_DF.shape[0] == 0):
            return None
        
        copy_df = QUOTES_DF.copy()
        
        # compute residuals of loan values with respect to par value, i.e. '100'
        copy_df['Residuals'] = (copy_df['Price'] - 100).abs()
        copy_df['Residuals'] = pd.to_numeric(copy_df['Residuals'])
        
        # create dataframe for best rates for all investors
        N_investors = len(self.investor_dict)
        optimal_quotes_df = pd.DataFrame( columns =['Rate','Price','Investor'],index=range(N_investors) )
        optimal_quotes_df['Price'] = 0.0
        i = 0
        
        
        for i, investor in zip(list(range(N_investors)), list(self.investor_dict.keys())):
            
            new_df = copy_df[ (copy_df['Investor'] == self.investor_dict[investor]) & (copy_df['Expired'] == False)]
            
            if new_df.shape[0] > 0:
                
                # get index of loan product with smallest residuals
                idx_min = new_df['Residuals'].argmin()
                
                # append to dataframe
                optimal_quotes_df.iat[i,0] = new_df.iat[idx_min,0]
                optimal_quotes_df.iat[i,1] = new_df.iat[idx_min,1]
                optimal_quotes_df.iat[i,2] = new_df.iat[idx_min,2]
        
            
        return optimal_quotes_df
    
    
    def par_values_test(self, OPTIMAL_QUOTES_DF: pd.DataFrame, LOWER_BOUND: float = 97.0, UPPER_BOUND: float = 103.0):
        
        if (type(OPTIMAL_QUOTES_DF) is type(None)) or (OPTIMAL_QUOTES_DF.shape[0] == 0):
            return None
        
        # construct new dataframe for test results
        par_value_results_df = OPTIMAL_QUOTES_DF.copy()
        par_value_results_df['Pass/Fail'] = 'Fail'
        
        # conduct 'Par-Value' test across all investors
        for i in range(len(par_value_results_df)):
        
            optimal_price = pd.to_numeric(float(OPTIMAL_QUOTES_DF.iat[i,1]))
        
            if (optimal_price >= LOWER_BOUND) and (optimal_price <= UPPER_BOUND):
                
                par_value_results_df.iat[i,3] = 'Pass'
            
        
        
        return par_value_results_df

# %%
pilot = Price_Engine_Pilot(USERNAME='mliuzza@makeabeeline.com',PASSWORD='retSEC201066$')

INPUT_SHEET = "OB_Test_Loans_Vesta INPUT.xlsx"
OUTPUT_SHEET = 'OB_Test_Loans_Vesta OUTPUT.xlsx'

# read excel sheet containing mortgage pricing parameters
testLoans_df = pd.read_excel(INPUT_SHEET)

# define output excel sheet
output_df = testLoans_df.head(1)

# add auxiliary columns
output_df['Pass/Fail'] = 'N/A'
output_df['Rate'] = 0
output_df['Price'] = 0

# get lists of all relevant testing parameters
LIST_loan_purpose = (testLoans_df['Loan Purpose'].drop_duplicates()).tolist()
LIST_occupancy = (testLoans_df['Occupancy'].drop_duplicates()).tolist()
LIST_channel = (testLoans_df['Channel'].drop_duplicates()).tolist()
LIST_property_type = (testLoans_df['Property type'].drop_duplicates()).tolist()
LIST_loan_type = (testLoans_df['Loan Type'].drop_duplicates()).tolist()
LIST_ppp = (testLoans_df['PPP'].drop_duplicates()).tolist()
LIST_investor = (testLoans_df['Investor'].drop_duplicates()).tolist()
LIST_id = (testLoans_df['Investor'].drop_duplicates()).tolist()


# open Vesta with first test loan
pilot.open_page(testLoans_df.at[0,'Vesta Loan'])
pilot.wait(3)
pilot.login_vesta()

# define loop variables
N_cases = testLoans_df.shape[0]
idx_input = 0
idx_output = output_df.shape[0] - 1

while idx_input < N_cases:
    
    # create new instance of LoanType for pricing test
    test_loan = TestLoan(LOAN_PURPOSE=testLoans_df.at[idx_input,'Loan Purpose'],LOAN_TYPE=testLoans_df.at[idx_input,'Loan Type'])
    test_loan.set_loan_parameters(OCCUPANCY=testLoans_df.at[idx_input,'Occupancy'],
                                    CHANNEL=testLoans_df.at[idx_input,'Channel'],
                                    STATE=testLoans_df.at[idx_input,'State'],
                                    PROPERTY_TYPE=testLoans_df.at[idx_input,'Property type'],
                                    PPP=testLoans_df.at[idx_input,'PPP'],
                                    INVESTOR=testLoans_df.at[idx_input,'Investor'],
                                    PRICING_VARIABLES = testLoans_df.at[idx_input,'Pricing Variables'],
                                    ID = testLoans_df.at[idx_input,'ID'])
    
    # set URL of test loan in vesta
    test_loan.set_vesta_url(URL=testLoans_df.at[idx_input,'Vesta Loan'])
    
    # get URL of test loan in vesta and open page
    pilot.open_page(URL=test_loan.get_vesta_url())
    pilot.wait(10)
    pilot.pull_credit()
    pilot.pull_fees()
    idx_output = pilot.run_pricing(TEST_LOAN=test_loan,INPUT_DF=testLoans_df,OUTPUT_DF=output_df,INPUT_NAME=INPUT_SHEET,OUTPUT_NAME=OUTPUT_SHEET,IDX=idx_output)
    pilot.wait(10)
    
    output_df = pd.read_excel(OUTPUT_SHEET)
    idx_input += 1


# close browser
pilot.wait(20)
pilot.close_browser()
# Out:
# Pricing iteration #0
# P&S
# Conv
# Florida
# Single Family
#
# Case iteration #0
# DTI < 45 LTV < 80 Credit_Score < 620
#
#       ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 5  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 6  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 7  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#    PPP        Investor                     Pricing Variables
# 5  NaN  Arc Home Loans  DTI < 45 LTV < 80 Credit_Score < 620  \
# 6  NaN      Mr. Cooper  DTI < 45 LTV < 80 Credit_Score < 620
# 7  NaN      Mr. Cooper  DTI < 45 LTV < 80 Credit_Score < 620
#
#                                           Vesta Loan   QC  Note Pass/Fail
# 5  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Pass  \
# 6  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Pass
# 7  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Pass
#
#     Rate    Price
# 5  7.625  100.145
# 6  7.625  100.168
# 7  7.625  100.168
#
#
# Case iteration #1
# DTI < 45 LTV < 80 Credit_Score > 740
#
#        ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 12  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 13  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 14  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#     PPP        Investor                     Pricing Variables
# 12  NaN  Arc Home Loans  DTI < 45 LTV < 80 Credit_Score > 740  \
# 13  NaN      Mr. Cooper  DTI < 45 LTV < 80 Credit_Score > 740
# 14  NaN      Mr. Cooper  DTI < 45 LTV < 80 Credit_Score > 740
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 12  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Pass  \
# 13  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Pass
# 14  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Pass
#
#      Rate    Price
# 12  6.500  100.000
# 13  6.625  100.195
# 14  6.625  100.195
#
#
# Case iteration #2
# DTI < 45 LTV > 80 Credit_Score < 620
#
#        ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 19  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 20  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 21  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#     PPP        Investor                     Pricing Variables
# 19  NaN  Arc Home Loans  DTI < 45 LTV > 80 Credit_Score < 620  \
# 20  NaN      Mr. Cooper  DTI < 45 LTV > 80 Credit_Score < 620
# 21  NaN      Mr. Cooper  DTI < 45 LTV > 80 Credit_Score < 620
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 19  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Pass  \
# 20  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Pass
# 21  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Pass
#
#      Rate    Price
# 19  7.625   99.485
# 20  8.125  100.050
# 21  8.125  100.050
#
#
# Case iteration #3
# DTI < 45 LTV > 80 Credit_Score > 740
#
#        ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 26  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 27  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 28  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#     PPP    Investor                     Pricing Variables
# 26  NaN         Arc  DTI < 45 LTV > 80 Credit_Score > 740  \
# 27  NaN  Mr. Cooper  DTI < 45 LTV > 80 Credit_Score > 740
# 28  NaN  Mr. Cooper  DTI < 45 LTV > 80 Credit_Score > 740
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 26  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail  \
# 27  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
# 28  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
#
#     Rate  Price
# 26   0.0    0.0
# 27   0.0    0.0
# 28   0.0    0.0
#
#
# Case iteration #4
# DTI < 45 LTV > 97 Credit_Score < 620
#
#        ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 33  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 34  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 35  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#     PPP    Investor                     Pricing Variables
# 33  NaN         Arc  DTI < 45 LTV > 97 Credit_Score < 620  \
# 34  NaN  Mr. Cooper  DTI < 45 LTV > 97 Credit_Score < 620
# 35  NaN  Mr. Cooper  DTI < 45 LTV > 97 Credit_Score < 620
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 33  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail  \
# 34  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
# 35  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
#
#     Rate  Price
# 33   0.0    0.0
# 34   0.0    0.0
# 35   0.0    0.0
#
#
# Case iteration #5
# DTI < 45 LTV > 97 Credit_Score > 740
#
#        ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 40  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 41  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 42  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#     PPP    Investor                     Pricing Variables
# 40  NaN         Arc  DTI < 45 LTV > 97 Credit_Score > 740  \
# 41  NaN  Mr. Cooper  DTI < 45 LTV > 97 Credit_Score > 740
# 42  NaN  Mr. Cooper  DTI < 45 LTV > 97 Credit_Score > 740
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 40  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail  \
# 41  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
# 42  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
#
#     Rate  Price
# 40   0.0    0.0
# 41   0.0    0.0
# 42   0.0    0.0
#
#
# Case iteration #6
# DTI > 50 LTV < 80 Credit_Score < 620
#
#        ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 47  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 48  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 49  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#     PPP    Investor                     Pricing Variables
# 47  NaN         Arc  DTI > 50 LTV < 80 Credit_Score < 620  \
# 48  NaN  Mr. Cooper  DTI > 50 LTV < 80 Credit_Score < 620
# 49  NaN  Mr. Cooper  DTI > 50 LTV < 80 Credit_Score < 620
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 47  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail  \
# 48  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
# 49  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
#
#     Rate  Price
# 47   0.0    0.0
# 48   0.0    0.0
# 49   0.0    0.0
#
#
# Case iteration #7
# DTI > 50 LTV < 80 Credit_Score > 740
#
#        ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 54  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 55  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 56  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#     PPP    Investor                     Pricing Variables
# 54  NaN         Arc  DTI > 50 LTV < 80 Credit_Score > 740  \
# 55  NaN  Mr. Cooper  DTI > 50 LTV < 80 Credit_Score > 740
# 56  NaN  Mr. Cooper  DTI > 50 LTV < 80 Credit_Score > 740
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 54  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail  \
# 55  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
# 56  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
#
#     Rate  Price
# 54   0.0    0.0
# 55   0.0    0.0
# 56   0.0    0.0
#
#
# Case iteration #8
# DTI > 50 LTV > 80 Credit_Score < 620
#
#        ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 61  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 62  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 63  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#     PPP    Investor                     Pricing Variables
# 61  NaN         Arc  DTI > 50 LTV > 80 Credit_Score < 620  \
# 62  NaN  Mr. Cooper  DTI > 50 LTV > 80 Credit_Score < 620
# 63  NaN  Mr. Cooper  DTI > 50 LTV > 80 Credit_Score < 620
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 61  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail  \
# 62  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
# 63  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
#
#     Rate  Price
# 61   0.0    0.0
# 62   0.0    0.0
# 63   0.0    0.0
#
#
# Case iteration #9
# DTI > 50 LTV > 80 Credit_Score > 740
#
#        ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 68  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 69  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 70  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#     PPP    Investor                     Pricing Variables
# 68  NaN         Arc  DTI > 50 LTV > 80 Credit_Score > 740  \
# 69  NaN  Mr. Cooper  DTI > 50 LTV > 80 Credit_Score > 740
# 70  NaN  Mr. Cooper  DTI > 50 LTV > 80 Credit_Score > 740
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 68  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail  \
# 69  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
# 70  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
#
#     Rate  Price
# 68   0.0    0.0
# 69   0.0    0.0
# 70   0.0    0.0
#
#
# Case iteration #10
# DTI > 50 LTV > 97 Credit_Score < 620
#
#        ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 75  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 76  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 77  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#     PPP    Investor                     Pricing Variables
# 75  NaN         Arc  DTI > 50 LTV > 97 Credit_Score < 620  \
# 76  NaN  Mr. Cooper  DTI > 50 LTV > 97 Credit_Score < 620
# 77  NaN  Mr. Cooper  DTI > 50 LTV > 97 Credit_Score < 620
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 75  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail  \
# 76  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
# 77  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
#
#     Rate  Price
# 75   0.0    0.0
# 76   0.0    0.0
# 77   0.0    0.0
#
#
# Case iteration #11
# DTI > 50 LTV > 97 Credit_Score > 740
#
#        ID Loan Purpose Occupancy Channel    State  Property type Loan Type
# 82  329.0          P&S   Primary  Retail  Florida  Single Family      Conv  \
# 83  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
# 84  329.0          P&S   Primary  Retail  Florida  Single Family      Conv
#
#     PPP    Investor                     Pricing Variables
# 82  NaN         Arc  DTI > 50 LTV > 97 Credit_Score > 740  \
# 83  NaN  Mr. Cooper  DTI > 50 LTV > 97 Credit_Score > 740
# 84  NaN  Mr. Cooper  DTI > 50 LTV > 97 Credit_Score > 740
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 82  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail  \
# 83  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
# 84  https://beeline.beta.vestatech.io/loans/bad2d3...  NaN   NaN      Fail
#
#     Rate  Price
# 82   0.0    0.0
# 83   0.0    0.0
# 84   0.0    0.0
#
#
# Pricing iteration #84
# P&S
# BS
# Florida
# Single Family
#
# Case iteration #0
# 12 mth
#
#     Unnamed: 0     ID Loan Purpose Occupancy Channel    State  Property type
# 89         NaN  331.0          P&S   Primary  Retail  Florida  Single Family  \
# 90         NaN  331.0          P&S   Primary  Retail  Florida  Single Family
# 91         NaN  331.0          P&S   Primary  Retail  Florida  Single Family
#
#    Loan Type  PPP    Investor Pricing Variables
# 89        BS  NaN         Arc            12 mth  \
# 90        BS  NaN  Mr. Cooper            12 mth
# 91        BS  NaN  Mr. Cooper            12 mth
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 89  https://beeline.beta.vestatech.io/loans/cfd53a...  NaN   NaN      Fail  \
# 90  https://beeline.beta.vestatech.io/loans/cfd53a...  NaN   NaN      Fail
# 91  https://beeline.beta.vestatech.io/loans/cfd53a...  NaN   NaN      Fail
#
#     Rate  Price
# 89   0.0    0.0
# 90   0.0    0.0
# 91   0.0    0.0
#
#
# Case iteration #1
# 24 mth
#
#     Unnamed: 0     ID Loan Purpose Occupancy Channel    State  Property type
# 96         NaN  331.0          P&S   Primary  Retail  Florida  Single Family  \
# 97         NaN  331.0          P&S   Primary  Retail  Florida  Single Family
# 98         NaN  331.0          P&S   Primary  Retail  Florida  Single Family
#
#    Loan Type  PPP    Investor Pricing Variables
# 96        BS  NaN         Arc            24 mth  \
# 97        BS  NaN  Mr. Cooper            24 mth
# 98        BS  NaN  Mr. Cooper            24 mth
#
#                                            Vesta Loan   QC  Note Pass/Fail
# 96  https://beeline.beta.vestatech.io/loans/cfd53a...  NaN   NaN      Fail  \
# 97  https://beeline.beta.vestatech.io/loans/cfd53a...  NaN   NaN      Fail
# 98  https://beeline.beta.vestatech.io/loans/cfd53a...  NaN   NaN      Fail
#
#     Rate  Price
# 96   0.0    0.0
# 97   0.0    0.0
# 98   0.0    0.0
#
#
# Pricing iteration #98
# P&S
# Conv
# Florida
# Multi Family
#
# Case iteration #0
# DTI < 45 LTV < 80 Credit_Score < 620
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 103           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 104           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 105           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP        Investor
# 103  Multi Family      Conv  NaN  Arc Home Loans  \
# 104  Multi Family      Conv  NaN      Mr. Cooper
# 105  Multi Family      Conv  NaN      Mr. Cooper
#
#                         Pricing Variables
# 103  DTI < 45 LTV < 80 Credit_Score < 620  \
# 104  DTI < 45 LTV < 80 Credit_Score < 620
# 105  DTI < 45 LTV < 80 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 103  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Pass  \
# 104  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Pass
# 105  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Pass
#
#       Rate   Price
# 103  7.625  99.770
# 104  8.125  99.925
# 105  8.125  99.925
#
#
# Case iteration #1
# DTI < 45 LTV < 80 Credit_Score > 740
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 110           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 111           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 112           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP        Investor
# 110  Multi Family      Conv  NaN  Arc Home Loans  \
# 111  Multi Family      Conv  NaN      Mr. Cooper
# 112  Multi Family      Conv  NaN      Mr. Cooper
#
#                         Pricing Variables
# 110  DTI < 45 LTV < 80 Credit_Score > 740  \
# 111  DTI < 45 LTV < 80 Credit_Score > 740
# 112  DTI < 45 LTV < 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 110  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Pass  \
# 111  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Pass
# 112  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Pass
#
#       Rate    Price
# 110  6.625  100.030
# 111  7.125  100.229
# 112  7.125  100.229
#
#
# Case iteration #2
# DTI < 45 LTV > 80 Credit_Score < 620
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 117           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 118           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 119           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP    Investor
# 117  Multi Family      Conv  NaN         NaN  \
# 118  Multi Family      Conv  NaN  Mr. Cooper
# 119  Multi Family      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 117  DTI < 45 LTV > 80 Credit_Score < 620  \
# 118  DTI < 45 LTV > 80 Credit_Score < 620
# 119  DTI < 45 LTV > 80 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 117  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail  \
# 118  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Pass
# 119  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Pass
#
#       Rate   Price
# 117    NaN   0.000
# 118  8.125  98.925
# 119  8.125  98.925
#
#
# Case iteration #3
# DTI < 45 LTV > 80 Credit_Score > 740
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 124           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 125           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 126           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP        Investor
# 124  Multi Family      Conv  NaN  Arc Home Loans  \
# 125  Multi Family      Conv  NaN      Mr. Cooper
# 126  Multi Family      Conv  NaN      Mr. Cooper
#
#                         Pricing Variables
# 124  DTI < 45 LTV > 80 Credit_Score > 740  \
# 125  DTI < 45 LTV > 80 Credit_Score > 740
# 126  DTI < 45 LTV > 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 124  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Pass  \
# 125  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Pass
# 126  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Pass
#
#       Rate    Price
# 124  7.500  100.109
# 125  7.625  100.249
# 126  7.625  100.249
#
#
# Case iteration #4
# DTI < 45 LTV > 97 Credit_Score < 620
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 131           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 132           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 133           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP    Investor
# 131  Multi Family      Conv  NaN         Arc  \
# 132  Multi Family      Conv  NaN  Mr. Cooper
# 133  Multi Family      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 131  DTI < 45 LTV > 97 Credit_Score < 620  \
# 132  DTI < 45 LTV > 97 Credit_Score < 620
# 133  DTI < 45 LTV > 97 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 131  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail  \
# 132  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
# 133  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
#
#      Rate  Price
# 131   0.0    0.0
# 132   0.0    0.0
# 133   0.0    0.0
#
#
# Case iteration #5
# DTI < 45 LTV > 97 Credit_Score > 740
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 138           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 139           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 140           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP    Investor
# 138  Multi Family      Conv  NaN         Arc  \
# 139  Multi Family      Conv  NaN  Mr. Cooper
# 140  Multi Family      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 138  DTI < 45 LTV > 97 Credit_Score > 740  \
# 139  DTI < 45 LTV > 97 Credit_Score > 740
# 140  DTI < 45 LTV > 97 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 138  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail  \
# 139  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
# 140  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
#
#      Rate  Price
# 138   0.0    0.0
# 139   0.0    0.0
# 140   0.0    0.0
#
#
# Case iteration #6
# DTI > 50 LTV < 80 Credit_Score < 620
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 145           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 146           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 147           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP    Investor
# 145  Multi Family      Conv  NaN         Arc  \
# 146  Multi Family      Conv  NaN  Mr. Cooper
# 147  Multi Family      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 145  DTI > 50 LTV < 80 Credit_Score < 620  \
# 146  DTI > 50 LTV < 80 Credit_Score < 620
# 147  DTI > 50 LTV < 80 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 145  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail  \
# 146  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
# 147  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
#
#      Rate  Price
# 145   0.0    0.0
# 146   0.0    0.0
# 147   0.0    0.0
#
#
# Case iteration #7
# DTI > 50 LTV < 80 Credit_Score > 740
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 152           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 153           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 154           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP    Investor
# 152  Multi Family      Conv  NaN         Arc  \
# 153  Multi Family      Conv  NaN  Mr. Cooper
# 154  Multi Family      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 152  DTI > 50 LTV < 80 Credit_Score > 740  \
# 153  DTI > 50 LTV < 80 Credit_Score > 740
# 154  DTI > 50 LTV < 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 152  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail  \
# 153  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
# 154  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
#
#      Rate  Price
# 152   0.0    0.0
# 153   0.0    0.0
# 154   0.0    0.0
#
#
# Case iteration #8
# DTI > 50 LTV > 80 Credit_Score < 620
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 159           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 160           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 161           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP    Investor
# 159  Multi Family      Conv  NaN         Arc  \
# 160  Multi Family      Conv  NaN  Mr. Cooper
# 161  Multi Family      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 159  DTI > 50 LTV > 80 Credit_Score < 620  \
# 160  DTI > 50 LTV > 80 Credit_Score < 620
# 161  DTI > 50 LTV > 80 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 159  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail  \
# 160  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
# 161  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
#
#      Rate  Price
# 159   0.0    0.0
# 160   0.0    0.0
# 161   0.0    0.0
#
#
# Case iteration #9
# DTI > 50 LTV > 80 Credit_Score > 740
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 166           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 167           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 168           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP    Investor
# 166  Multi Family      Conv  NaN         Arc  \
# 167  Multi Family      Conv  NaN  Mr. Cooper
# 168  Multi Family      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 166  DTI > 50 LTV > 80 Credit_Score > 740  \
# 167  DTI > 50 LTV > 80 Credit_Score > 740
# 168  DTI > 50 LTV > 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 166  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail  \
# 167  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
# 168  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
#
#      Rate  Price
# 166   0.0    0.0
# 167   0.0    0.0
# 168   0.0    0.0
#
#
# Case iteration #10
# DTI > 50 LTV > 97 Credit_Score < 620
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 173           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 174           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 175           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP    Investor
# 173  Multi Family      Conv  NaN         Arc  \
# 174  Multi Family      Conv  NaN  Mr. Cooper
# 175  Multi Family      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 173  DTI > 50 LTV > 97 Credit_Score < 620  \
# 174  DTI > 50 LTV > 97 Credit_Score < 620
# 175  DTI > 50 LTV > 97 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 173  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail  \
# 174  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
# 175  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
#
#      Rate  Price
# 173   0.0    0.0
# 174   0.0    0.0
# 175   0.0    0.0
#
#
# Case iteration #11
# DTI > 50 LTV > 97 Credit_Score > 740
#
#      Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy Channel    State
# 180           NaN         NaN  334.0          P&S   Primary  Retail  Florida  \
# 181           NaN         NaN  334.0          P&S   Primary  Retail  Florida
# 182           NaN         NaN  334.0          P&S   Primary  Retail  Florida
#
#     Property type Loan Type  PPP    Investor
# 180  Multi Family      Conv  NaN         Arc  \
# 181  Multi Family      Conv  NaN  Mr. Cooper
# 182  Multi Family      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 180  DTI > 50 LTV > 97 Credit_Score > 740  \
# 181  DTI > 50 LTV > 97 Credit_Score > 740
# 182  DTI > 50 LTV > 97 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 180  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail  \
# 181  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
# 182  https://beeline.beta.vestatech.io/loans/a0ef56...  NaN   NaN      Fail
#
#      Rate  Price
# 180   0.0    0.0
# 181   0.0    0.0
# 182   0.0    0.0
#
#
# Pricing iteration #182
# P&S
# BS
# Florida
# Multi Family
#
# Case iteration #0
# 12 mth
#
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy
# 187           NaN           NaN         NaN  336.0          P&S   Primary  \
# 188           NaN           NaN         NaN  336.0          P&S   Primary
# 189           NaN           NaN         NaN  336.0          P&S   Primary
#
#     Channel    State Property type Loan Type  PPP        Investor
# 187  Retail  Florida  Multi Family        BS  NaN  Arc Home Loans  \
# 188  Retail  Florida  Multi Family        BS  NaN      Mr. Cooper
# 189  Retail  Florida  Multi Family        BS  NaN      Mr. Cooper
#
#     Pricing Variables                                         Vesta Loan   QC
# 187            12 mth  https://beeline.beta.vestatech.io/loans/567a0b...  NaN  \
# 188            12 mth  https://beeline.beta.vestatech.io/loans/567a0b...  NaN
# 189            12 mth  https://beeline.beta.vestatech.io/loans/567a0b...  NaN
#
#      Note Pass/Fail  Rate    Price
# 187   NaN      Pass  6.25  100.074
# 188   NaN      Pass  6.50  100.073
# 189   NaN      Pass  6.50  100.073
#
#
# Case iteration #1
# 24 mth
#
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose Occupancy
# 194           NaN           NaN         NaN  336.0          P&S   Primary  \
# 195           NaN           NaN         NaN  336.0          P&S   Primary
# 196           NaN           NaN         NaN  336.0          P&S   Primary
#
#     Channel    State Property type Loan Type  PPP        Investor
# 194  Retail  Florida  Multi Family        BS  NaN  Arc Home Loans  \
# 195  Retail  Florida  Multi Family        BS  NaN      Mr. Cooper
# 196  Retail  Florida  Multi Family        BS  NaN      Mr. Cooper
#
#     Pricing Variables                                         Vesta Loan   QC
# 194            24 mth  https://beeline.beta.vestatech.io/loans/567a0b...  NaN  \
# 195            24 mth  https://beeline.beta.vestatech.io/loans/567a0b...  NaN
# 196            24 mth  https://beeline.beta.vestatech.io/loans/567a0b...  NaN
#
#      Note Pass/Fail  Rate    Price
# 194   NaN      Pass  6.25  100.074
# 195   NaN      Pass  6.50  100.073
# 196   NaN      Pass  6.50  100.073
#
#
# Pricing iteration #196
# P&S
# Conv
# Florida
# Condo
#
# Case iteration #0
# DTI < 45 LTV < 80 Credit_Score < 620
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 201           NaN           NaN           NaN         NaN  339.0          P&S  \
# 202           NaN           NaN           NaN         NaN  339.0          P&S
# 203           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP        Investor
# 201   Primary  Retail  Florida         Condo      Conv  NaN  Arc Home Loans  \
# 202   Primary  Retail  Florida         Condo      Conv  NaN      Mr. Cooper
# 203   Primary  Retail  Florida         Condo      Conv  NaN      Mr. Cooper
#
#                         Pricing Variables
# 201  DTI < 45 LTV < 80 Credit_Score < 620  \
# 202  DTI < 45 LTV < 80 Credit_Score < 620
# 203  DTI < 45 LTV < 80 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 201  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Pass  \
# 202  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Pass
# 203  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Pass
#
#       Rate    Price
# 201  7.625  100.020
# 202  7.625  100.043
# 203  7.625  100.043
#
#
# Case iteration #1
# DTI < 45 LTV < 80 Credit_Score > 740
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 208           NaN           NaN           NaN         NaN  339.0          P&S  \
# 209           NaN           NaN           NaN         NaN  339.0          P&S
# 210           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP    Investor
# 208   Primary  Retail  Florida         Condo      Conv  NaN         Arc  \
# 209   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
# 210   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 208  DTI < 45 LTV < 80 Credit_Score > 740  \
# 209  DTI < 45 LTV < 80 Credit_Score > 740
# 210  DTI < 45 LTV < 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 208  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail  \
# 209  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
# 210  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
#
#      Rate  Price
# 208   0.0    0.0
# 209   0.0    0.0
# 210   0.0    0.0
#
#
# Case iteration #2
# DTI < 45 LTV > 80 Credit_Score < 620
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 215           NaN           NaN           NaN         NaN  339.0          P&S  \
# 216           NaN           NaN           NaN         NaN  339.0          P&S
# 217           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP        Investor
# 215   Primary  Retail  Florida         Condo      Conv  NaN  Arc Home Loans  \
# 216   Primary  Retail  Florida         Condo      Conv  NaN      Mr. Cooper
# 217   Primary  Retail  Florida         Condo      Conv  NaN      Mr. Cooper
#
#                         Pricing Variables
# 215  DTI < 45 LTV > 80 Credit_Score < 620  \
# 216  DTI < 45 LTV > 80 Credit_Score < 620
# 217  DTI < 45 LTV > 80 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 215  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Pass  \
# 216  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Pass
# 217  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Pass
#
#       Rate   Price
# 215  7.625  98.735
# 216  8.125  99.390
# 217  8.125  99.390
#
#
# Case iteration #3
# DTI < 45 LTV > 80 Credit_Score > 740
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 222           NaN           NaN           NaN         NaN  339.0          P&S  \
# 223           NaN           NaN           NaN         NaN  339.0          P&S
# 224           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP        Investor
# 222   Primary  Retail  Florida         Condo      Conv  NaN  Arc Home Loans  \
# 223   Primary  Retail  Florida         Condo      Conv  NaN      Mr. Cooper
# 224   Primary  Retail  Florida         Condo      Conv  NaN      Mr. Cooper
#
#                         Pricing Variables
# 222  DTI < 45 LTV > 80 Credit_Score > 740  \
# 223  DTI < 45 LTV > 80 Credit_Score > 740
# 224  DTI < 45 LTV > 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 222  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Pass  \
# 223  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Pass
# 224  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Pass
#
#       Rate    Price
# 222  7.625  100.283
# 223  7.375  100.077
# 224  7.375  100.077
#
#
# Case iteration #4
# DTI < 45 LTV > 97 Credit_Score < 620
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 229           NaN           NaN           NaN         NaN  339.0          P&S  \
# 230           NaN           NaN           NaN         NaN  339.0          P&S
# 231           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP    Investor
# 229   Primary  Retail  Florida         Condo      Conv  NaN         Arc  \
# 230   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
# 231   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 229  DTI < 45 LTV > 97 Credit_Score < 620  \
# 230  DTI < 45 LTV > 97 Credit_Score < 620
# 231  DTI < 45 LTV > 97 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 229  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail  \
# 230  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
# 231  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
#
#      Rate  Price
# 229   0.0    0.0
# 230   0.0    0.0
# 231   0.0    0.0
#
#
# Case iteration #5
# DTI < 45 LTV > 97 Credit_Score > 740
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 236           NaN           NaN           NaN         NaN  339.0          P&S  \
# 237           NaN           NaN           NaN         NaN  339.0          P&S
# 238           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP    Investor
# 236   Primary  Retail  Florida         Condo      Conv  NaN         Arc  \
# 237   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
# 238   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 236  DTI < 45 LTV > 97 Credit_Score > 740  \
# 237  DTI < 45 LTV > 97 Credit_Score > 740
# 238  DTI < 45 LTV > 97 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 236  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail  \
# 237  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
# 238  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
#
#      Rate  Price
# 236   0.0    0.0
# 237   0.0    0.0
# 238   0.0    0.0
#
#
# Case iteration #6
# DTI > 50 LTV < 80 Credit_Score < 620
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 243           NaN           NaN           NaN         NaN  339.0          P&S  \
# 244           NaN           NaN           NaN         NaN  339.0          P&S
# 245           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP    Investor
# 243   Primary  Retail  Florida         Condo      Conv  NaN         Arc  \
# 244   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
# 245   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 243  DTI > 50 LTV < 80 Credit_Score < 620  \
# 244  DTI > 50 LTV < 80 Credit_Score < 620
# 245  DTI > 50 LTV < 80 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 243  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail  \
# 244  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
# 245  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
#
#      Rate  Price
# 243   0.0    0.0
# 244   0.0    0.0
# 245   0.0    0.0
#
#
# Case iteration #7
# DTI > 50 LTV < 80 Credit_Score > 740
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 250           NaN           NaN           NaN         NaN  339.0          P&S  \
# 251           NaN           NaN           NaN         NaN  339.0          P&S
# 252           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP    Investor
# 250   Primary  Retail  Florida         Condo      Conv  NaN         Arc  \
# 251   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
# 252   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 250  DTI > 50 LTV < 80 Credit_Score > 740  \
# 251  DTI > 50 LTV < 80 Credit_Score > 740
# 252  DTI > 50 LTV < 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 250  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail  \
# 251  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
# 252  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
#
#      Rate  Price
# 250   0.0    0.0
# 251   0.0    0.0
# 252   0.0    0.0
#
#
# Case iteration #8
# DTI > 50 LTV > 80 Credit_Score < 620
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 257           NaN           NaN           NaN         NaN  339.0          P&S  \
# 258           NaN           NaN           NaN         NaN  339.0          P&S
# 259           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP    Investor
# 257   Primary  Retail  Florida         Condo      Conv  NaN         Arc  \
# 258   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
# 259   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 257  DTI > 50 LTV > 80 Credit_Score < 620  \
# 258  DTI > 50 LTV > 80 Credit_Score < 620
# 259  DTI > 50 LTV > 80 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 257  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail  \
# 258  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
# 259  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
#
#      Rate  Price
# 257   0.0    0.0
# 258   0.0    0.0
# 259   0.0    0.0
#
#
# Case iteration #9
# DTI > 50 LTV > 80 Credit_Score > 740
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 264           NaN           NaN           NaN         NaN  339.0          P&S  \
# 265           NaN           NaN           NaN         NaN  339.0          P&S
# 266           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP    Investor
# 264   Primary  Retail  Florida         Condo      Conv  NaN         Arc  \
# 265   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
# 266   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 264  DTI > 50 LTV > 80 Credit_Score > 740  \
# 265  DTI > 50 LTV > 80 Credit_Score > 740
# 266  DTI > 50 LTV > 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 264  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail  \
# 265  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
# 266  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
#
#      Rate  Price
# 264   0.0    0.0
# 265   0.0    0.0
# 266   0.0    0.0
#
#
# Case iteration #10
# DTI > 50 LTV > 97 Credit_Score < 620
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 271           NaN           NaN           NaN         NaN  339.0          P&S  \
# 272           NaN           NaN           NaN         NaN  339.0          P&S
# 273           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP    Investor
# 271   Primary  Retail  Florida         Condo      Conv  NaN         Arc  \
# 272   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
# 273   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 271  DTI > 50 LTV > 97 Credit_Score < 620  \
# 272  DTI > 50 LTV > 97 Credit_Score < 620
# 273  DTI > 50 LTV > 97 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 271  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail  \
# 272  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
# 273  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
#
#      Rate  Price
# 271   0.0    0.0
# 272   0.0    0.0
# 273   0.0    0.0
#
#
# Case iteration #11
# DTI > 50 LTV > 97 Credit_Score > 740
#
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     ID Loan Purpose
# 278           NaN           NaN           NaN         NaN  339.0          P&S  \
# 279           NaN           NaN           NaN         NaN  339.0          P&S
# 280           NaN           NaN           NaN         NaN  339.0          P&S
#
#     Occupancy Channel    State Property type Loan Type  PPP    Investor
# 278   Primary  Retail  Florida         Condo      Conv  NaN         Arc  \
# 279   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
# 280   Primary  Retail  Florida         Condo      Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 278  DTI > 50 LTV > 97 Credit_Score > 740  \
# 279  DTI > 50 LTV > 97 Credit_Score > 740
# 280  DTI > 50 LTV > 97 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note Pass/Fail
# 278  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail  \
# 279  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
# 280  https://beeline.beta.vestatech.io/loans/120933...  NaN   NaN      Fail
#
#      Rate  Price
# 278   0.0    0.0
# 279   0.0    0.0
# 280   0.0    0.0
#
#
# Pricing iteration #280
# P&S
# BS
# Florida
# Condo
#
# Case iteration #0
# 12 mth
#
#      Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0
# 285           NaN           NaN           NaN           NaN         NaN  \
# 286           NaN           NaN           NaN           NaN         NaN
# 287           NaN           NaN           NaN           NaN         NaN
#
#         ID Loan Purpose Occupancy Channel    State  ... Loan Type PPP
# 285  341.0          P&S   Primary  Retail  Florida  ...        BS NaN  \
# 286  341.0          P&S   Primary  Retail  Florida  ...        BS NaN
# 287  341.0          P&S   Primary  Retail  Florida  ...        BS NaN
#
#            Investor Pricing Variables
# 285  Arc Home Loans            12 mth  \
# 286      Mr. Cooper            12 mth
# 287      Mr. Cooper            12 mth
#
#                                             Vesta Loan   QC Note  Pass/Fail
# 285  https://beeline.beta.vestatech.io/loans/790924...  NaN  NaN       Pass  \
# 286  https://beeline.beta.vestatech.io/loans/790924...  NaN  NaN       Pass
# 287  https://beeline.beta.vestatech.io/loans/790924...  NaN  NaN       Pass
#
#       Rate    Price
# 285  6.250  100.074
# 286  6.375  100.089
# 287  6.375  100.089
#
# [3 rows x 21 columns]
#
#
# Case iteration #1
# 24 mth
#
#      Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0
# 292           NaN           NaN           NaN           NaN         NaN  \
# 293           NaN           NaN           NaN           NaN         NaN
# 294           NaN           NaN           NaN           NaN         NaN
#
#         ID Loan Purpose Occupancy Channel    State  ... Loan Type PPP
# 292  341.0          P&S   Primary  Retail  Florida  ...        BS NaN  \
# 293  341.0          P&S   Primary  Retail  Florida  ...        BS NaN
# 294  341.0          P&S   Primary  Retail  Florida  ...        BS NaN
#
#        Investor Pricing Variables
# 292         Arc            24 mth  \
# 293  Mr. Cooper            24 mth
# 294  Mr. Cooper            24 mth
#
#                                             Vesta Loan   QC Note  Pass/Fail
# 292  https://beeline.beta.vestatech.io/loans/790924...  NaN  NaN       Fail  \
# 293  https://beeline.beta.vestatech.io/loans/790924...  NaN  NaN       Fail
# 294  https://beeline.beta.vestatech.io/loans/790924...  NaN  NaN       Fail
#
#     Rate  Price
# 292  0.0    0.0
# 293  0.0    0.0
# 294  0.0    0.0
#
# [3 rows x 21 columns]
#
#
# Pricing iteration #294
# P&S
# Conv
# Florida
# Single Family
#
# Case iteration #0
# DTI < 45 LTV < 80 Credit_Score < 620
#
# ...
#
#      Unnamed: 0.16  Unnamed: 0.15  Unnamed: 0.14  Unnamed: 0.13
# 600            NaN            NaN            NaN            NaN  \
# 601            NaN            NaN            NaN            NaN
# 602            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.12  Unnamed: 0.11  ...  Loan Type  PPP        Investor
# 600            NaN            NaN  ...       Conv  NaN  Arc Home Loans  \
# 601            NaN            NaN  ...       Conv  NaN      Mr. Cooper
# 602            NaN            NaN  ...       Conv  NaN      Mr. Cooper
#
#                         Pricing Variables
# 600  DTI < 45 LTV < 80 Credit_Score > 740  \
# 601  DTI < 45 LTV < 80 Credit_Score > 740
# 602  DTI < 45 LTV < 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note  Pass/Fail
# 600  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Pass  \
# 601  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Pass
# 602  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Pass
#
#      Rate    Price
# 600  7.00  100.223
# 601  7.99  100.147
# 602  7.99  100.147
#
# [3 rows x 37 columns]
#
#
# Case iteration #2
# DTI < 45 LTV > 80 Credit_Score < 620
#
#      Unnamed: 0.20  Unnamed: 0.19  Unnamed: 0.18  Unnamed: 0.17
# 607            NaN            NaN            NaN            NaN  \
# 608            NaN            NaN            NaN            NaN
# 609            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.16  Unnamed: 0.15  Unnamed: 0.14  Unnamed: 0.13
# 607            NaN            NaN            NaN            NaN  \
# 608            NaN            NaN            NaN            NaN
# 609            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.12  Unnamed: 0.11  ...  Loan Type  PPP    Investor
# 607            NaN            NaN  ...       Conv  NaN         Arc  \
# 608            NaN            NaN  ...       Conv  NaN  Mr. Cooper
# 609            NaN            NaN  ...       Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 607  DTI < 45 LTV > 80 Credit_Score < 620  \
# 608  DTI < 45 LTV > 80 Credit_Score < 620
# 609  DTI < 45 LTV > 80 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note  Pass/Fail
# 607  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail  \
# 608  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
# 609  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
#
#      Rate  Price
# 607   0.0    0.0
# 608   0.0    0.0
# 609   0.0    0.0
#
# [3 rows x 37 columns]
#
#
# Case iteration #3
# DTI < 45 LTV > 80 Credit_Score > 740
#
#      Unnamed: 0.20  Unnamed: 0.19  Unnamed: 0.18  Unnamed: 0.17
# 614            NaN            NaN            NaN            NaN  \
# 615            NaN            NaN            NaN            NaN
# 616            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.16  Unnamed: 0.15  Unnamed: 0.14  Unnamed: 0.13
# 614            NaN            NaN            NaN            NaN  \
# 615            NaN            NaN            NaN            NaN
# 616            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.12  Unnamed: 0.11  ...  Loan Type  PPP        Investor
# 614            NaN            NaN  ...       Conv  NaN  Arc Home Loans  \
# 615            NaN            NaN  ...       Conv  NaN      Mr. Cooper
# 616            NaN            NaN  ...       Conv  NaN      Mr. Cooper
#
#                         Pricing Variables
# 614  DTI < 45 LTV > 80 Credit_Score > 740  \
# 615  DTI < 45 LTV > 80 Credit_Score > 740
# 616  DTI < 45 LTV > 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note  Pass/Fail
# 614  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Pass  \
# 615  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Pass
# 616  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Pass
#
#       Rate   Price
# 614  7.625  97.235
# 615  8.125  97.890
# 616  8.125  97.890
#
# [3 rows x 37 columns]
#
#
# Case iteration #4
# DTI < 45 LTV > 97 Credit_Score < 620
#
#      Unnamed: 0.20  Unnamed: 0.19  Unnamed: 0.18  Unnamed: 0.17
# 621            NaN            NaN            NaN            NaN  \
# 622            NaN            NaN            NaN            NaN
# 623            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.16  Unnamed: 0.15  Unnamed: 0.14  Unnamed: 0.13
# 621            NaN            NaN            NaN            NaN  \
# 622            NaN            NaN            NaN            NaN
# 623            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.12  Unnamed: 0.11  ...  Loan Type  PPP    Investor
# 621            NaN            NaN  ...       Conv  NaN         Arc  \
# 622            NaN            NaN  ...       Conv  NaN  Mr. Cooper
# 623            NaN            NaN  ...       Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 621  DTI < 45 LTV > 97 Credit_Score < 620  \
# 622  DTI < 45 LTV > 97 Credit_Score < 620
# 623  DTI < 45 LTV > 97 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note  Pass/Fail
# 621  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail  \
# 622  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
# 623  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
#
#      Rate  Price
# 621   0.0    0.0
# 622   0.0    0.0
# 623   0.0    0.0
#
# [3 rows x 37 columns]
#
#
# Case iteration #5
# DTI < 45 LTV > 97 Credit_Score > 740
#
#      Unnamed: 0.20  Unnamed: 0.19  Unnamed: 0.18  Unnamed: 0.17
# 628            NaN            NaN            NaN            NaN  \
# 629            NaN            NaN            NaN            NaN
# 630            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.16  Unnamed: 0.15  Unnamed: 0.14  Unnamed: 0.13
# 628            NaN            NaN            NaN            NaN  \
# 629            NaN            NaN            NaN            NaN
# 630            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.12  Unnamed: 0.11  ...  Loan Type  PPP    Investor
# 628            NaN            NaN  ...       Conv  NaN         Arc  \
# 629            NaN            NaN  ...       Conv  NaN  Mr. Cooper
# 630            NaN            NaN  ...       Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 628  DTI < 45 LTV > 97 Credit_Score > 740  \
# 629  DTI < 45 LTV > 97 Credit_Score > 740
# 630  DTI < 45 LTV > 97 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note  Pass/Fail
# 628  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail  \
# 629  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
# 630  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
#
#      Rate  Price
# 628   0.0    0.0
# 629   0.0    0.0
# 630   0.0    0.0
#
# [3 rows x 37 columns]
#
#
# Case iteration #6
# DTI > 50 LTV < 80 Credit_Score < 620
#
#      Unnamed: 0.20  Unnamed: 0.19  Unnamed: 0.18  Unnamed: 0.17
# 635            NaN            NaN            NaN            NaN  \
# 636            NaN            NaN            NaN            NaN
# 637            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.16  Unnamed: 0.15  Unnamed: 0.14  Unnamed: 0.13
# 635            NaN            NaN            NaN            NaN  \
# 636            NaN            NaN            NaN            NaN
# 637            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.12  Unnamed: 0.11  ...  Loan Type  PPP    Investor
# 635            NaN            NaN  ...       Conv  NaN         Arc  \
# 636            NaN            NaN  ...       Conv  NaN  Mr. Cooper
# 637            NaN            NaN  ...       Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 635  DTI > 50 LTV < 80 Credit_Score < 620  \
# 636  DTI > 50 LTV < 80 Credit_Score < 620
# 637  DTI > 50 LTV < 80 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note  Pass/Fail
# 635  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail  \
# 636  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
# 637  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
#
#      Rate  Price
# 635   0.0    0.0
# 636   0.0    0.0
# 637   0.0    0.0
#
# [3 rows x 37 columns]
#
#
# Case iteration #7
# DTI > 50 LTV < 80 Credit_Score > 740
#
#      Unnamed: 0.20  Unnamed: 0.19  Unnamed: 0.18  Unnamed: 0.17
# 642            NaN            NaN            NaN            NaN  \
# 643            NaN            NaN            NaN            NaN
# 644            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.16  Unnamed: 0.15  Unnamed: 0.14  Unnamed: 0.13
# 642            NaN            NaN            NaN            NaN  \
# 643            NaN            NaN            NaN            NaN
# 644            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.12  Unnamed: 0.11  ...  Loan Type  PPP    Investor
# 642            NaN            NaN  ...       Conv  NaN         Arc  \
# 643            NaN            NaN  ...       Conv  NaN  Mr. Cooper
# 644            NaN            NaN  ...       Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 642  DTI > 50 LTV < 80 Credit_Score > 740  \
# 643  DTI > 50 LTV < 80 Credit_Score > 740
# 644  DTI > 50 LTV < 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note  Pass/Fail
# 642  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail  \
# 643  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
# 644  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
#
#      Rate  Price
# 642   0.0    0.0
# 643   0.0    0.0
# 644   0.0    0.0
#
# [3 rows x 37 columns]
#
#
# Case iteration #8
# DTI > 50 LTV > 80 Credit_Score < 620
#
#      Unnamed: 0.20  Unnamed: 0.19  Unnamed: 0.18  Unnamed: 0.17
# 649            NaN            NaN            NaN            NaN  \
# 650            NaN            NaN            NaN            NaN
# 651            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.16  Unnamed: 0.15  Unnamed: 0.14  Unnamed: 0.13
# 649            NaN            NaN            NaN            NaN  \
# 650            NaN            NaN            NaN            NaN
# 651            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.12  Unnamed: 0.11  ...  Loan Type  PPP    Investor
# 649            NaN            NaN  ...       Conv  NaN         Arc  \
# 650            NaN            NaN  ...       Conv  NaN  Mr. Cooper
# 651            NaN            NaN  ...       Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 649  DTI > 50 LTV > 80 Credit_Score < 620  \
# 650  DTI > 50 LTV > 80 Credit_Score < 620
# 651  DTI > 50 LTV > 80 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note  Pass/Fail
# 649  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail  \
# 650  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
# 651  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
#
#      Rate  Price
# 649   0.0    0.0
# 650   0.0    0.0
# 651   0.0    0.0
#
# [3 rows x 37 columns]
#
#
# Case iteration #9
# DTI > 50 LTV > 80 Credit_Score > 740
#
#      Unnamed: 0.20  Unnamed: 0.19  Unnamed: 0.18  Unnamed: 0.17
# 656            NaN            NaN            NaN            NaN  \
# 657            NaN            NaN            NaN            NaN
# 658            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.16  Unnamed: 0.15  Unnamed: 0.14  Unnamed: 0.13
# 656            NaN            NaN            NaN            NaN  \
# 657            NaN            NaN            NaN            NaN
# 658            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.12  Unnamed: 0.11  ...  Loan Type  PPP    Investor
# 656            NaN            NaN  ...       Conv  NaN         Arc  \
# 657            NaN            NaN  ...       Conv  NaN  Mr. Cooper
# 658            NaN            NaN  ...       Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 656  DTI > 50 LTV > 80 Credit_Score > 740  \
# 657  DTI > 50 LTV > 80 Credit_Score > 740
# 658  DTI > 50 LTV > 80 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note  Pass/Fail
# 656  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail  \
# 657  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
# 658  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
#
#      Rate  Price
# 656   0.0    0.0
# 657   0.0    0.0
# 658   0.0    0.0
#
# [3 rows x 37 columns]
#
#
# Case iteration #10
# DTI > 50 LTV > 97 Credit_Score < 620
#
#      Unnamed: 0.20  Unnamed: 0.19  Unnamed: 0.18  Unnamed: 0.17
# 663            NaN            NaN            NaN            NaN  \
# 664            NaN            NaN            NaN            NaN
# 665            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.16  Unnamed: 0.15  Unnamed: 0.14  Unnamed: 0.13
# 663            NaN            NaN            NaN            NaN  \
# 664            NaN            NaN            NaN            NaN
# 665            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.12  Unnamed: 0.11  ...  Loan Type  PPP    Investor
# 663            NaN            NaN  ...       Conv  NaN         Arc  \
# 664            NaN            NaN  ...       Conv  NaN  Mr. Cooper
# 665            NaN            NaN  ...       Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 663  DTI > 50 LTV > 97 Credit_Score < 620  \
# 664  DTI > 50 LTV > 97 Credit_Score < 620
# 665  DTI > 50 LTV > 97 Credit_Score < 620
#
#                                             Vesta Loan   QC  Note  Pass/Fail
# 663  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail  \
# 664  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
# 665  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
#
#      Rate  Price
# 663   0.0    0.0
# 664   0.0    0.0
# 665   0.0    0.0
#
# [3 rows x 37 columns]
#
#
# Case iteration #11
# DTI > 50 LTV > 97 Credit_Score > 740
#
#      Unnamed: 0.20  Unnamed: 0.19  Unnamed: 0.18  Unnamed: 0.17
# 670            NaN            NaN            NaN            NaN  \
# 671            NaN            NaN            NaN            NaN
# 672            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.16  Unnamed: 0.15  Unnamed: 0.14  Unnamed: 0.13
# 670            NaN            NaN            NaN            NaN  \
# 671            NaN            NaN            NaN            NaN
# 672            NaN            NaN            NaN            NaN
#
#      Unnamed: 0.12  Unnamed: 0.11  ...  Loan Type  PPP    Investor
# 670            NaN            NaN  ...       Conv  NaN         Arc  \
# 671            NaN            NaN  ...       Conv  NaN  Mr. Cooper
# 672            NaN            NaN  ...       Conv  NaN  Mr. Cooper
#
#                         Pricing Variables
# 670  DTI > 50 LTV > 97 Credit_Score > 740  \
# 671  DTI > 50 LTV > 97 Credit_Score > 740
# 672  DTI > 50 LTV > 97 Credit_Score > 740
#
#                                             Vesta Loan   QC  Note  Pass/Fail
# 670  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail  \
# 671  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
# 672  https://beeline.beta.vestatech.io/loans/d96516...  NaN   NaN       Fail
#
#      Rate  Price
# 670   0.0    0.0
# 671   0.0    0.0
# 672   0.0    0.0
#
# [3 rows x 37 columns]
